# %% [markdown]
# # Area Business Coverage

# %%
import pandas as pd
import numpy as np
# !conda install -c conda-forge folium -y
import folium
import matplotlib as mpl
import matplotlib.pyplot as plt
import requests
import json
from sklearn.cluster import DBSCAN
from IPython.display import display
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.11.0              |             py_0          61 KB  conda-forge
#     certifi-2020.6.20          |   py36h9f0ad1d_0         151 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     ca-certificates-2020.6.20  |       hecda079_0         145 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_1         2.1 MB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     branca:          0.4.1-py_0        conda-forge
#     folium:          0.11.0-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:         2020.6.20-py36_0              --> 2020.6.20-py36h9f0ad1d_0 conda-forge
#     openssl:         1.1.1g-h7b6447c_0             --> 1.1.1g-h516909a_1        conda-forge
#
# The following packages will be DOWNGRADED:
#
#     ca-certificates: 2020.6.24-0                   --> 2020.6.20-hecda079_0     conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.11.0        | 61 KB     | ##################################### | 100%
# certifi-2020.6.20    | 151 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# ca-certificates-2020 | 145 KB    | ##################################### | 100%
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ### Getting Data

# %%
# @hidden_cell
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret

# %%
VERSION = '20180604'
base_url = 'https://api.foursquare.com/v2/venues/search'
basic_params = {
    'client_id':CLIENT_ID,
    'client_secret':CLIENT_SECRET,
    'v':VERSION
}

# %%
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black']

# %%
def shortenCategory(data,maxName=25):
    # Cleaning category
    temp = data['Category']
    temp = temp.split('(')[0]
    temp = temp.split('/')[0]
    temp.strip()
    data['Category'] = temp
    
    # Shortening Name
    temp = data['Name']
    if(len(temp)>maxName+3):
        temp = temp[:maxName-1].strip() + '..'
    data['Name'] = temp
    return data

# %%
def SummarizeLocation(search,minDistance=0.0003,minLocations=3):
    # Determining wether the input is
    # in (latitude,longitude) or
    # string location
    seg = search.split(',')
    ll = 0
    try:
        seg[0] = float(seg[0])
        seg[1] = float(seg[1])
        ll = 1
    except:
        pass
    
    # Modifying api parameters to
    # set search query
    if(len(seg)==2 and ll):
        params = {'ll':search}
    else:
        params = {'near':search}
    
    # Number of Nerby locations
    params['limit'] = 1000  
    
    # Combining credentials with
    # search query
    params = {**basic_params, **params}
    
    # Retriving Data from API
    data = json.loads(requests.get(base_url,params=params).text)['response']['venues']
    
    # Creating Empty databse ro store cleaned data
    database = pd.DataFrame(columns=['name','address','lat','lng','catgName','catgShort'])
    
    # Cleaning and storing data
    # in database
    for place in data:
        try:
            database = database.append({
                'name'     : place['name'],
                'address'  : place['location']['formattedAddress'][0] or place['location']['address'] ,
                'lat'      : place['location']['labeledLatLngs'][0]['lat'] ,
                'lng'      : place['location']['labeledLatLngs'][0]['lng'],
                'catgName' : place['categories'][0]['name'] ,
                'catgShort': place['categories'][0]['shortName'] 
            },ignore_index=True)
        except:
            pass
    
    # retriving data for clustering and display
    locations = database[['lat','lng','name','catgName']].copy()
    
    # DBSCAN clustering
    clustering = DBSCAN(eps=minDistance, min_samples=minLocations)
    clustering.fit(locations[['lat','lng']])
    
    # Categorising locations into clusters
    locations['cluster'] = clustering.labels_
    
    # Empty Folium Map
    resMap = folium.Map(location=[locations['lat'].mean(),locations['lng'].mean()],zoom_start=20)
    
    # Recording positions on map based
    # on their latitude and longitude
    occurences = folium.map.FeatureGroup()
    for lat,lng,name,color,category in zip(locations['lat'],locations['lng'],locations['name'],locations['cluster'],locations['catgName']):
        occurences.add_child(
            folium.vector_layers.CircleMarker(
                [lat, lng],
                color='black',
                radius = 5,
                fill=True,
                fill_color=colors[color],
                fill_opacity=0.6,
                tooltip =name + f" ({category})"
            )
        )
    resMap.add_child(occurences)   
    display(resMap)
    
    # Summarizing Data
    print('Area Summary')
    summary = database.copy()
    summary['cluster'] = locations['cluster'].copy()
    
    # Cleaning data for short Summary
    for cluster in sorted(set(clustering.labels_)):
        if(cluster!=-1):
            temp = summary[summary['cluster']==cluster][['name','catgName']].copy()
            temp.columns = ['Name','Category']
            temp.reset_index(drop=True,inplace=True)
            temp.index+=1
            temp = temp.apply(shortenCategory,axis=1)
            print(f'Cluster {cluster}'.ljust(12))
            print('‾'*12)
            print(temp[['Category','Name']])
            print('\n\n')
    temp = summary[summary['cluster']==-1][['name','catgName']].copy()
    temp.columns = ['Name','Category']
    temp.reset_index(drop=True,inplace=True)
    temp.index+=1
    temp = temp.apply(shortenCategory,axis=1)
    print(f'Remaining'.ljust(12))
    print('‾'*12)
    print(temp[['Category','Name']])
    print('\n\n')

# %%
search = '40.7149555,-74.0153365' # Input

# %%
SummarizeLocation(search,0.0002,5)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
# Area Summary
# Cluster 0
# ‾‾‾‾‾‾‾‾‾‾‾‾
#               Category                         Name
# 1        Movie Theater           Regal Battery Park
# 2         Burger Joint                  Shake Shack
# 3     Asian Restaurant                     Wei West
# 4          Pizza Place    Harry's Italian Pizza Bar
# 5        Grocery Store         Battery Place Market
# 6            Juice Bar                     Dr Smood
# 7            Wine Shop            Vintry Fine Wines
# 8          Salad Place               Beans & Greens
# 9   Miscellaneous Shop               Artsee Eyewear
# 10                Park   No Active Recreation Bench
# 11            Building  26th Floor of 250 Vesey/WFC
# 12                Bank       citibank west broadway
# 13           Gift Shop                      Accents
#
#
#
# Cluster 1
# ‾‾‾‾‾‾‾‾‾‾‾‾
#                    Category                        Name
# 1        Mexican Restaurant                      El Vez
# 2                Bagel Shop                Pick A Bagel
# 3                 BBQ Joint                  Blue Smoke
# 4                      Gym    Conrad New York Fitness..
# 5        Seafood Restaurant                   Seamore’s
# 6               Coffee Shop           Starbucks Reserve
# 7                  Bus Stop   Downtown Connection Bus..
# 8                 Hotel Bar                Conrad Lobby
# 9                    Salon       Salvatore Barber Salon
# 10           Clothing Store                      Vince.
# 11              Art Gallery  World Financial Center C..
# 12                      ATM       Bank of America - ATM
# 13                 Bus Stop   MTA Bus - M22 (Vesey St..
# 14  Health & Beauty Service                      DryBar
# 15            Burrito Place                 Burrito Bar
# 16                   Office                   Jones Day
# 17           Clothing Store                 Fair Harbor
# 18               Food Court     WFC Shops & Restaurants
# 19                 Bus Line                M22 Bus Stop
# 20                 Bus Line    MTA Bus - M20 (Vesey St)
# 21              Bus Station  Sim 33 Express Bus At Ve..
# 22               Nail Salon                    Glosslab
# 23              Coffee Shop          The Coffee Beanery
# 24                   Office   Batteryparkcity.com North
# 25               Food Truck         Bombay Biryani Cart
# 26       Spanish Restaurant               Bocadillo Bar
# 27            Women's Store             & other stories
# 28                   Office            Escalate @ 4 WFC
# 29             Tech Startup            Classicalite.com
# 30                Hotel Bar              Atrio roof top
# 31          Other Nightlife               North End Way
# 32              Bus Station  Transbridge - Wall St. t..
#
#
#
# Cluster 2
# ‾‾‾‾‾‾‾‾‾‾‾‾
#                  Category                          Name
# 1             Flower Shop                         Bloom
# 2                  Office                 Goldman Sachs
# 3   Corporate Coffee Shop          3rd Floor Coffee Bar
# 4     Corporate Cafeteria       Goldman Sachs Cafeteria
# 5      Real Estate Office  Brookfield Office Properties
# 6     Corporate Cafeteria          Sky Lobby Coffee Bar
# 7          Medical Center   Goldman Sachs Health Center
# 8                    Café     Brooklyn Roasting Company
# 9            Bike Rental              Citi Bike Station
# 10            Bus Station     MTA B - M20 - Murray St..
# 11           Optical Shop        ThirdEyeChic Optometry
# 12        Doctor's Office          HSS Physical Therapy
# 13            Candy Store                        S.B.O.
# 14               Bus Line    MTA M22 Bus - Battery Pa..
# 15                 Office        Hadyen Investments LLC
# 16       Business Service            Hadyen Capital LLC
#
#
#
# Cluster 3
# ‾‾‾‾‾‾‾‾‾‾‾‾
#             Category                          Name
# 1           Bus Stop    MTA Bus - Vesey St & Wes..
# 2           Bus Stop  Verizon Bus To Basking Ridge
# 3          Gift Shop    American Express Gift Ca..
# 4        Post Office    Pitney Bowes Mail Soluti..
# 5    Conference Room            Global HR Townhall
# 6  Convenience Store            Amex Airport Store
#
#
#
# Remaining
# ‾‾‾‾‾‾‾‾‾‾‾‾
#                     Category                          Name
# 1                      Hotel      Conrad New York Downtown
# 2                   Building        One World Trade Center
# 3                Event Space               Conrad Ballroom
# 4                  Monument          Irish Hunger Memorial
# 5                 Steakhouse           Del Frisco's Grille
# 6         Italian Restaurant                          Parm
# 7                Bus Station    MTA MaBSTOA Bus M20 /.M2..
# 8            Assisted Living               2 River Terrace
# 9      Residential Building                 The Riverhouse
# 10                   Library     New York Public Library..
# 11  Mediterranean Restaurant                Atrio New York
# 12                    Office                     Vox Media
# 13                   Dog Run    Stuyvesant High School D..
# 14                    Bakery             Le Pain Quotidien
# 15                    Office                   200 West St
# 16     Residential Building                 The Riverhouse
# 17                Auditorium      Goldman Sachs Auditorium
# 18                       Gym                 Asphalt Green
# 19             Boat or Ferry              True Sailing NYC
# 20              Bike Rental              Citi Bike Station
# 21               Event Space      Battery Park Conservancy
# 22                    Office     Bank of America Merrill..
# 23                 Hotel Bar       Loopy Doopy Rooftop Bar
# 24                 Juice Bar              Elixir Juice Bar
# 25           Business Center          Spectrum Science NYC
# 26                       Gym      The Gym @ The Riverhouse
# 27                    Office    Saks Off Fifth Corporate..
# 28                Eye Doctor     Manhattan Eye Specialists
# 29                     Hotel    North End Ave & Murray S..
# 30                      Gym              Conrad Hilton Gym
# 31                       Gym     2 River Terrace Fitness..
# 32       Rental Car Location           Enterprise CarShare
# 33                 Bike Shop                       Peloton
# 34             Burrito Place            California Burrito
# 35                  Building    102 North End Ave Hunter..
# 36           Coworking Space                  INTL FCStone
# 37      Other Great Outdoors                Parking Garage
# 38                    Office     Merrill Lynch Sound Stage
# 39           Coworking Space    American Express Bluepri..
# 40                  Building  Enterprise Growth University
# 41                    Office            Contingent Capital
# 42                       Gym                  200 West Gym
# 43          Basketball Court    Strong Healthy Woman Boo..

# %% [markdown]
# ## A sample map if the map above is not visible

# %% [markdown]
# <img src="map.png">
